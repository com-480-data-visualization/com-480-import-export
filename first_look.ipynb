# %%
# import and read csv files in pd dataframe
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import data_manipulation_functions as dmf
import importlib
import warnings

# %%
importlib.reload(dmf)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
path_exp_1988_2011 = 'dataset/OGD_EXP_TN_M/OGD_EXP_TN_M_1988_2011.csv'
manipulator_exp_1988_2011 = dmf.DataManipulator(path_exp_1988_2011, 'Exported goods, 1988-2011')
# Out:
# Starting to parse the date

# %%
path_imp_1988_2011 = 'dataset/OGD_IMP_TN_M/OGD_IMP_TN_M_1988_2011.csv'
manipulator_imp_1988_2011 = dmf.DataManipulator(path_imp_1988_2011, 'Imported goods, 1988-2011')
# Out:
# Starting to parse the date

# %%
path_exp_from_2012 = 'dataset/OGD_EXP_TN_M/OGD_EXP_TN_M_from_2012.csv'
manipulator_exp_from_2012 = dmf.DataManipulator(path_exp_from_2012, 'Exported goods, 2012-2022')
# Out:
# Starting to parse the date

# %%
path_imp_from_2012 = 'dataset/OGD_IMP_TN_M/OGD_IMP_TN_M_from_2012.csv'
manipulator_imp_from_2012 = dmf.DataManipulator(path_imp_from_2012, 'Imported goods, 2012-2022')
# Out:
# Starting to parse the date

# %%
manipulator_exp_1988_2011.first_graph()
manipulator_imp_1988_2011.first_graph()
manipulator_exp_from_2012.first_graph()
manipulator_imp_from_2012.first_graph()
