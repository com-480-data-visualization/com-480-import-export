# %%
# import and read csv files in pd dataframe
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import data_manipulation_functions as dmf
import importlib
import warnings

# %%
importlib.reload(dmf)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
path_imp_1988_2011 = 'dataset/OGD_IMP_TN_M/OGD_IMP_TN_M_1988_2011.csv'
path_imp_from_2012 = 'dataset/OGD_IMP_TN_M/OGD_IMP_TN_M_from_2012.csv'

path_exp_1988_2011 = 'dataset/OGD_EXP_TN_M/OGD_EXP_TN_M_1988_2011.csv'
path_exp_from_2012 = 'dataset/OGD_EXP_TN_M/OGD_EXP_TN_M_from_2012.csv'


imports = dmf.DataManipulator([path_imp_1988_2011, path_imp_from_2012], 'Import')
exports = dmf.DataManipulator([path_exp_1988_2011, path_exp_from_2012], 'Export')

imports.display()
#exports.display()
# Out:
# Starting to parse the date
# Starting to parse the date
#   traffic_direction       date   tn_num  ctry_id       chf  kg  month  year
# 0               IMP 1988-01-01  101.110      112   14000.0 NaN      1  1988
# 1               IMP 1988-01-01  101.191      111    1850.0 NaN      1  1988
# 2               IMP 1988-01-01  101.199      111  594321.0 NaN      1  1988
# 3               IMP 1988-01-01  101.199      112  176589.0 NaN      1  1988
# 4               IMP 1988-01-01  101.199      113    2250.0 NaN      1  1988

# %%
imports.graphs()
exports.graphs()

# %%
imports.get_product_name(101.110)
imports.get_product_graph(101.110)
# Out:
# Product: Chevaux reproducteurs de race pure
# Product: Chevaux reproducteurs de race pure
#         traffic_direction       date  tn_num  ctry_id       chf      kg  \
# 0                     IMP 1988-01-01  101.11      112   14000.0     NaN
# 35761                 IMP 1988-02-01  101.11      111    5450.0     NaN
# 35762                 IMP 1988-02-01  101.11      121    3500.0     NaN
# 74671                 IMP 1988-03-01  101.11      112   42295.0     NaN
# 115439                IMP 1988-04-01  101.11      111   53770.0     NaN
# ...                   ...        ...     ...      ...       ...     ...
# 3517261               IMP 1995-05-01  101.11      111   35279.0  2080.0
# 3517262               IMP 1995-05-01  101.11      112   18133.0  1040.0
# 3561049               IMP 1995-06-01  101.11      111   30006.0  3640.0
# 3561050               IMP 1995-06-01  101.11      115  200000.0   520.0
# 3561051               IMP 1995-06-01  101.11      122    4900.0   520.0
#
# ...
